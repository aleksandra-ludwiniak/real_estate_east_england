# %% [markdown]
# ## Data preprocessing and analysis PART I

# %% [markdown]
# ### Libraries:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import calendar
from scipy import stats
import numpy as np
import math
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import calplot
import json
import geopandas as gpd
import statistics
from statsmodels.api import OLS, add_constant
from bokeh.plotting import figure, show, output_file
from bokeh.models import ColumnDataSource, NumeralTickFormatter, Legend, LegendItem
from bokeh.palettes import Category10
from bokeh.io import output_notebook

# %% [markdown]
# ### Loading housing data:
# https://data.cambridgeshireinsight.org.uk/dataset/house-sales-and-prices

# %%
df1 = pd.read_csv('../data/ons-existing-homes-count-corrected_0.csv').sort_values('Area')
df2 = pd.read_csv('../data/ons-existing-homes-median-price-corrected_0_0.csv').sort_values('Area')
df3 = pd.read_csv('../data/ons-new-build-count-corrected_0.csv').sort_values('Area')
df4 = pd.read_csv('../data/ons-new-build-median-price-corrected_0.csv').sort_values('Area')

# %%
df2
# Out:
#     ONS code                  Area  Q4-1995  Q1-1996  Q2-1996  Q3-1996  \
# 1  E07000008             Cambridge    69500    69950    70000    72000
# 2  E07000009   East Cambridgeshire    56500    56500    57000    57000
# 3  E07000010               Fenland    40000    40000    40000    40000
# 6  E07000201          Forest Heath    49000    49000    48000    47975
# 4  E07000011       Huntingdonshire    54000    54000    54000    54625
# 0  E06000031          Peterborough    40500    40000    40000    40000
# 5  E07000012  South Cambridgeshire    69950    70000    70000    73125
# 7  E07000204        St Edmundsbury    53500    53500    53625    54000
#
#    Q4-1996  Q1-1997  Q2-1997  Q3-1997  ...  Q3-2013  Q4-2013  Q1-2014  \
# 1    72500    73000    75000    78500  ...   290000   295000   295000
# 2    57500    58000    58500    59000  ...   196011   195750   197000
# 3    40000    40000    41500    43000  ...   127000   130000   135000
# 6    48000    49000    50000    52500  ...   149999   150000   151000
# 4    54875    55000    56000    57000  ...   177000   178000   179995
# 0    41000    41500    42000    43000  ...   125000   125000   129250
# 5    74000    74000    75500    77500  ...   250000   250000   250000
# 7    54995    55000    56625    57000  ...   186000   190000   192500
#
#    Q2-2014  Q3-2014  Q4-2014  Q1-2015  Q2-2015  Q3-2015  Q4-2015
# 1   304075   315000   327350   337000   350000   370000   380000
# 2   200000   204050   215000   220000   226000   229950   240000
# 3   137000   139995   140000   141000   145000   147500   150000
# 6   155000   160000   164950   168500   170000   175000   179500
# 4   184500   190000   195000   198000   200000   210000   215000
# 0   132750   135100   138000   140000   143500   145000   148000
# 5   250000   259875   266500   275000   284000   300000   315000
# 7   196000   208000   215000   215000   225000   227748   231000
#
# [8 rows x 83 columns]

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# Since there are only data from december 1995 we remove all data from 2015 and thery only have data from 1996-2015

# %%
df1.drop(columns="Q4-1995", inplace=True)
df2.drop(columns="Q4-1995", inplace=True)
df3.drop(columns="Q4-1995", inplace=True)
df4.drop(columns="Q4-1995", inplace=True)

# %% [markdown]
# According to wikipedia: "St Edmundsbury and Forest Heath were merged on 1 April 2019 to form the new West Suffolk district"
# https://en.wikipedia.org/wiki/Borough_of_St_Edmundsbury \
# Therfore we merge the data for these two areas in order to compare over the years.
# We add the amount of houses sold in data 1 and 3 and find the median price in data 2 and 4.

# %%
areas_to_merge = ['Forest Heath', 'St Edmundsbury']
new_area_name = 'West Suffolk'
new_ons_code = 'E07000245'

# %%
merge_df = df1[df1['Area'].isin(areas_to_merge)]
merged_row = merge_df.select_dtypes(include=[np.number]).sum()
merged_row_df = pd.DataFrame([merged_row], columns=merge_df.columns.drop(['ONS code', 'Area']))
merged_row_df['ONS code'] = new_ons_code
merged_row_df['Area'] = new_area_name

df1 = df1[~df1['Area'].isin(areas_to_merge)]
df1 = pd.concat([df1, merged_row_df], ignore_index=True)

df1
# Out:
#     ONS code                  Area  Q1-1996  Q2-1996  Q3-1996  Q4-1996  \
# 0  E07000008             Cambridge     1438     1458     1546     1718
# 1  E07000009   East Cambridgeshire      940      964     1014     1139
# 2  E07000010               Fenland     1214     1262     1296     1389
# 3  E07000011       Huntingdonshire     2575     2713     2910     3157
# 4  E06000031          Peterborough     2212     2194     2356     2530
# 5  E07000012  South Cambridgeshire     1773     1789     1928     2172
# 6  E07000245          West Suffolk     2104     2204     2393     2638
#
#    Q1-1997  Q2-1997  Q3-1997  Q4-1997  ...  Q3-2013  Q4-2013  Q1-2014  \
# 0     1829     1979     2095     2102  ...     1293     1320     1383
# 1     1172     1268     1362     1396  ...     1166     1264     1337
# 2     1491     1610     1763     1875  ...     1379     1439     1562
# 3     3347     3443     3485     3364  ...     2419     2699     2926
# 4     2628     2808     2921     3022  ...     1927     2021     2162
# 5     2280     2442     2563     2519  ...     1986     2054     2195
# 6     2751     2972     3133     3182  ...     2431     2579     2731
#
#    Q2-2014  Q3-2014  Q4-2014  Q1-2015  Q2-2015  Q3-2015  Q4-2015
# 0     1412     1366     1378     1352     1327     1345     1310
# 1     1423     1462     1448     1428     1405     1308     1312
# 2     1649     1684     1708     1617     1563     1597     1660
# 3     3076     3328     3296     3182     3118     2975     2938
# 4     2218     2407     2460     2428     2423     2453     2488
# 5     2311     2380     2416     2351     2231     2133     2151
# 6     2890     3022     3114     2982     2881     2842     2895
#
# [7 rows x 82 columns]

# %%
merge_df = df3[df3['Area'].isin(areas_to_merge)]
merged_row = merge_df.select_dtypes(include=[np.number]).sum()
merged_row_df = pd.DataFrame([merged_row], columns=merge_df.columns.drop(['ONS code', 'Area']))
merged_row_df['ONS code'] = new_ons_code
merged_row_df['Area'] = new_area_name

df3 = df3[~df3['Area'].isin(areas_to_merge)]
df3 = pd.concat([df3, merged_row_df], ignore_index=True)
df3
# Out:
#     ONS code                  Area  Q1-1996  Q2-1996  Q3-1996  Q4-1996  \
# 0  E07000008             Cambridge      169      140      169      198
# 1  E07000009   East Cambridgeshire      324      389      445      483
# 2  E07000010               Fenland      252      215      209      199
# 3  E07000011       Huntingdonshire      589      578      591      616
# 4  E06000031          Peterborough      266      278      328      365
# 5  E07000012  South Cambridgeshire      339      354      397      396
# 6  E07000245          West Suffolk      477      492      527      545
#
#    Q1-1997  Q2-1997  Q3-1997  Q4-1997  ...  Q3-2013  Q4-2013  Q1-2014  \
# 0      240      239      230      176  ...      595      669      724
# 1      488      486      468      453  ...      151      136      143
# 2      211      220      254      262  ...      114      116      121
# 3      643      668      673      639  ...      345      411      428
# 4      370      413      411      428  ...      485      561      626
# 5      430      485      550      558  ...      372      388      417
# 6      568      599      577      541  ...      254      239      283
#
#    Q2-2014  Q3-2014  Q4-2014  Q1-2015  Q2-2015  Q3-2015  Q4-2015
# 0      703      606      580      530      457      363      255
# 1      125      122      124      109      104       91       80
# 2      126      120      126      117       92       86       78
# 3      457      444      388      385      353      319      281
# 4      651      669      644      614      562      572      501
# 5      445      451      453      420      403      372      312
# 6      291      339      379      360      387      360      330
#
# [7 rows x 82 columns]

# %%
#merge 'Forest Heath' and 'St Edmundsbury' in data frames with prices - df2 and df4

def process_df(df, areas_to_merge, new_area_name, new_ons_code):
    merge_df = df[df['Area'].isin(areas_to_merge)]
    
    merged_row = merge_df.select_dtypes(include=[np.number]).mean()
    merged_row_df = pd.DataFrame([merged_row], columns=merge_df.columns.drop(['ONS code', 'Area']))
    merged_row_df['ONS code'] = new_ons_code
    merged_row_df['Area'] = new_area_name
    df = df[~df['Area'].isin(areas_to_merge)]
    return pd.concat([df, merged_row_df], ignore_index=True)

df2 = process_df(df2, areas_to_merge, new_area_name, new_ons_code)
df4 = process_df(df4, areas_to_merge, new_area_name, new_ons_code)

# %% [markdown]
# Reshaping data:

# %%
df1_flip = df1.melt(id_vars=['ONS code', 'Area'], var_name='Quarter', value_name='Houses Sold')
df2_flip = df2.melt(id_vars=['ONS code', 'Area'], var_name='Quarter', value_name='Price')
df3_flip = df3.melt(id_vars=['ONS code', 'Area'], var_name='Quarter', value_name='Houses Sold')
df4_flip = df4.melt(id_vars=['ONS code', 'Area'], var_name='Quarter', value_name='Price')

# %% [markdown]
# Extracting features:

# %%
# Extract year and quarter
df1_flip[['Quarter', 'Year']] = df1_flip['Quarter'].str.split('-', expand=True)
df2_flip[['Quarter', 'Year']] = df2_flip['Quarter'].str.split('-', expand=True)
df3_flip[['Quarter', 'Year']] = df3_flip['Quarter'].str.split('-', expand=True)
df4_flip[['Quarter', 'Year']] = df4_flip['Quarter'].str.split('-', expand=True)

# Convert Year to integer
df1_flip['Year'] = df1_flip['Year'].astype(int)
df2_flip['Year'] = df2_flip['Year'].astype(int)
df3_flip['Year'] = df3_flip['Year'].astype(int)
df4_flip['Year'] = df4_flip['Year'].astype(int)

# %%
# Combine data frames df1 and df2 for resale market
df_resale_market = pd.merge(df1_flip, df2_flip[['ONS code', 'Area', 'Quarter', 'Year', 'Price']],
                          on=['ONS code', 'Area', 'Quarter', 'Year'], how='left')
df_resale_market
# Out:
#       ONS code                  Area Quarter  Houses Sold  Year     Price
# 0    E07000008             Cambridge      Q1         1438  1996   69950.0
# 1    E07000009   East Cambridgeshire      Q1          940  1996   56500.0
# 2    E07000010               Fenland      Q1         1214  1996   40000.0
# 3    E07000011       Huntingdonshire      Q1         2575  1996   54000.0
# 4    E06000031          Peterborough      Q1         2212  1996   40000.0
# ..         ...                   ...     ...          ...   ...       ...
# 555  E07000010               Fenland      Q4         1660  2015  150000.0
# 556  E07000011       Huntingdonshire      Q4         2938  2015  215000.0
# 557  E06000031          Peterborough      Q4         2488  2015  148000.0
# 558  E07000012  South Cambridgeshire      Q4         2151  2015  315000.0
# 559  E07000245          West Suffolk      Q4         2895  2015  205250.0
#
# [560 rows x 6 columns]

# %%
# Combine data frames df3 and df4 for primary market
df_primary_market = pd.merge(df3_flip, df4_flip[['ONS code', 'Area', 'Quarter', 'Year', 'Price']],
                          on=['ONS code', 'Area', 'Quarter', 'Year'], how='left')
df_primary_market
# Out:
#       ONS code                  Area Quarter  Houses Sold  Year     Price
# 0    E07000008             Cambridge      Q1          169  1996   90000.0
# 1    E07000009   East Cambridgeshire      Q1          324  1996   69950.0
# 2    E07000010               Fenland      Q1          252  1996   47950.0
# 3    E07000011       Huntingdonshire      Q1          589  1996   83000.0
# 4    E06000031          Peterborough      Q1          266  1996   50000.0
# ..         ...                   ...     ...          ...   ...       ...
# 555  E07000010               Fenland      Q4           78  2015  152500.0
# 556  E07000011       Huntingdonshire      Q4          281  2015  197000.0
# 557  E06000031          Peterborough      Q4          501  2015  179995.0
# 558  E07000012  South Cambridgeshire      Q4          312  2015  345000.0
# 559  E07000245          West Suffolk      Q4          330  2015  229495.0
#
# [560 rows x 6 columns]

# %% [markdown]
# # Price trends for all districts over the years

# %% [markdown]
# Below is an analysis of apartment prices on the primary and secondary markets for subsequent districts. In order to best compare prices and their changes between districts, charts were created for each district and then superimposed on one chart. Additionally, we used linear regression to check the average annual change for each district, which allowed us to predict the dynamics of changes in subsequent years.

# %% [markdown]
# ### PRIMARY MARKET

# %% [markdown]
# ### - for each quarter

# %%
df_primary_market['Year_Quarter'] = df_primary_market['Year'].astype(str) + ' ' + df_primary_market['Quarter']
df_primary_market.sort_values(by='Year_Quarter', inplace=True)

areas = df_primary_market['Area'].unique()


for area in areas:
    area_data = df_primary_market[df_primary_market['Area'] == area]
    
    # Extract only the year part from 'Year_Quarter' for ticks
    labels = area_data['Year_Quarter'].tolist()
    year_ticks = [label for index, label in enumerate(labels) if index % 4 == 0] 
    fig = px.line(area_data, x='Year_Quarter', y='Price', 
                  title=f'Price Trend for {area}', 
                  labels={'Year_Quarter': 'Year and Quarter', 'Price': 'Price'},
                  markers=True,
                  color_discrete_sequence=['green']) 

    fig.update_xaxes(tickvals=[labels.index(tick) for tick in year_ticks], ticktext=[tick.split()[0] for tick in year_ticks])
    
    fig.update_layout(
        xaxis_title='Year and Quarter',
        yaxis_title='Price',
        xaxis=dict(tickangle=45),
        template='plotly_white',
        autosize=True
    )
    
    fig.show()
# Out:
# <div>                            <div id="3257bcea-94bb-455c-b518-04de311af3be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3257bcea-94bb-455c-b518-04de311af3be")) {                    Plotly.newPlot(                        "3257bcea-94bb-455c-b518-04de311af3be",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q
                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4"],"xaxis":"x","y":[63497.5,65600.0,64497.5,63735.0,63349.0,66099.0,68181.5,70225.0,72037.5,76000.0,76837.5,80375.0,81852.0,86459.5,90237.5,94975.0,99622.5,98872.5,104425.0,110425.0,111562.5,114550.0,115461.5,120610.0,125722.5,139499.0,146862.5,159000.0,159124.0,146972.5,139737.5,140844.0,144085.0,156972.5,162917.5,164779.0,167746.5,183750.0,178225.0,173111.5,171236.5,168747.5,173735.5,183747.5,193747.5,201610.5,196874.0,201372.5,194999.0,177749.0,181974.0,170085.5,172651.0,169975.0,166360.0,162013.0,163237.5,161875.0,162474.0,157475.0,156250.0,153500.0,165475.0,185000.0,191496.5,191305.0,186522.5,186399.0,187000.0,187997.5,189747.5,187750.0,179250.0,188746.5,183587.5,184734.0,215495.0,219995.0,223234.0,229495.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2 ...

# %%
# For each area, fit a linear regression model and forecast prices
for area in areas:
    area_data = df_primary_market[df_primary_market['Area'] == area]

    # Prepare data for regression
    area_data['Year_Index'] = area_data['Year'].astype(int) - area_data['Year'].astype(int).min()
    X = add_constant(area_data['Year_Index'])  # Adds a constant term to the predictor
    y = area_data['Price']

    # Fit the regression model
    model = OLS(y, X).fit()
    
    # Print summary of regression
    print(f"Regression summary for {area}:\n", model.summary())

    # forecast for the next 5 years
    forecast_years = pd.DataFrame({'Year_Index': range(area_data['Year_Index'].max() + 1, area_data['Year_Index'].max() + 6)})
    forecast_years = add_constant(forecast_years)  # Add the constant term
    predictions = model.predict(forecast_years)

    # create a DataFrame for plotting forecasted values
    forecasted_data = pd.DataFrame({
        'Year_Quarter': [str(year) + ' Q1' for year in range(area_data['Year'].max() + 1, area_data['Year'].max() + 6)],
        'Price': predictions
    })

    # combine historical and forecasted data
    combined_data = pd.concat([area_data, forecasted_data])

    # Plotting with Plotly
    fig = px.line(combined_data, x='Year_Quarter', y='Price', 
                  title=f'Price Trend and Forecast for {area}', 
                  labels={'Year_Quarter': 'Year and Quarter', 'Price': 'Price'},
                  markers=True,
                  color_discrete_sequence=['green'])

    fig.update_layout(
        xaxis_title='Year and Quarter',
        yaxis_title='Price',
        xaxis=dict(tickangle=45),
        template='plotly_white',
        autosize=True
    )

    fig.show()
# Out:
# Regression summary for Cambridge:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.769
# Method:                 Least Squares   F-statistic:                     263.7
# Date:                Mon, 06 May 2024   Prob (F-statistic):           9.77e-27
# Time:                        20:38:16   Log-Likelihood:                -969.51
# No. Observations:                  80   AIC:                             1943.
# Df Residuals:                      78   BIC:                             1948.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.313e+04   9678.080      9.623      0.000    7.39e+04    1.12e+05
# Year_Index  1.414e+04    870.875     16.238      0.000    1.24e+04    1.59e+04
# ==============================================================================
# Omnibus:                        4.651   Durbin-Watson:                   0.239
# Prob(Omnibus):                  0.098   Jarque-Bera (JB):                4.753
# Skew:                           0.279   Prob(JB):                       0.0929
# Kurtosis:                       4.056   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/p5/8kc_v4413nsdcn4002zvhcv80000gn/T/ipykernel_11621/3374400604.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id
"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f9 ...
# Regression summary for Fenland:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.777
# Method:                 Least Squares   F-statistic:                     275.6
# Date:                Mon, 06 May 2024   Prob (F-statistic):           2.54e-27
# Time:                        20:38:16   Log-Likelihood:                -894.68
# No. Observations:                  80   AIC:                             1793.
# Df Residuals:                      78   BIC:                             1798.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        5.94e+04   3798.383     15.638      0.000    5.18e+04     6.7e+04
# Year_Index  5674.6034    341.795     16.602      0.000    4994.142    6355.064
# ==============================================================================
# Omnibus:                       17.226   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               10.393
# Skew:                           0.728   Prob(JB):                      0.00554
# Kurtosis:                       2.000   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/p5/8kc_v4413nsdcn4002zvhcv80000gn/T/ipykernel_11621/3374400604.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="a4d53901-b65c-49b9-82b8-8e396bf4f6f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4d53901-b65c-49b9-82b8-8e396bf4f6f8")) {                    Plotly.newPlot(                        "a4d53901-b65c-49b9-82b8-8e396bf4f6f8",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4","2016 Q1","2017 Q1","2018 Q1","2019 Q1","2020 Q1"],"xaxis":"x","y":[47950.0,47950.0,47950.0,47950.0,47950.0,52000.0,54950.0,54950.0,54950.0,54950.0,55500.0,56950.0,59500.0,59950.0,59950.0,64000.0,63975.0,65950.0,67950.0,69950.0,69950.0,74950.0,74950.0,83250.0,87498.0,97500.0,104998.0,109950.0,110000.0,117000.0,128498.0,130000.0,139000.0,139000.0,139000.0,139950.0,139950.0,139000.0,142000.0,140000.0,142995.0,135000.0,134950.0,136000.0,135000.0,140000.0,142000.0,142000.0,148000.0,149000.0,149000.0,142000.0,135000.0,132500.0,125000.0,124250.0,125000.0,125000.0,135500.0,135000.0,138000.0,145000.0,142000.0,145000.0,142000.0,139995.0,139973.0,139475.0,139000.0,135000.0,142495.0,144000.0,143000.0,147998.0,143000.0,149995.0,149995.0,153998.0,157250.0,152500.0,172890.06052631576,178564.6639097744,184239.26729323305,189913.8706766917,195588.47406015033],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"typ ...
# Regression summary for Huntingdonshire:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     288.8
# Date:                Mon, 06 May 2024   Prob (F-statistic):           6.05e-28
# Time:                        20:38:16   Log-Likelihood:                -904.65
# No. Observations:                  80   AIC:                             1813.
# Df Residuals:                      78   BIC:                             1818.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.024e+05   4302.601     23.792      0.000    9.38e+04    1.11e+05
# Year_Index  6580.1145    387.166     16.996      0.000    5809.326    7350.903
# ==============================================================================
# Omnibus:                       11.875   Durbin-Watson:                   0.105
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                6.589
# Skew:                           0.522   Prob(JB):                       0.0371
# Kurtosis:                       2.059   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/p5/8kc_v4413nsdcn4002zvhcv80000gn/T/ipykernel_11621/3374400604.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="65ea1219-acce-4f5b-98ec-6466720b937a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65ea1219-acce-4f5b-98ec-6466720b937a")) {                    Plotly.newPlot(                        "65ea1219-acce-4f5b-98ec-6466720b937a",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q

# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        1.14e+05   4760.849     23.946      0.000    1.05e+05    1.23e+05
# Year_Index  8798.5389    428.401     20.538      0.000    7945.657    9651.421
# ==============================================================================
# Omnibus:                        3.513   Durbin-Watson:                   0.164
# Prob(Omnibus):                  0.173   Jarque-Bera (JB):                3.190
# Skew:                           0.408   Prob(JB):                        0.203
# Kurtosis:                       2.461   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/p5/8kc_v4413nsdcn4002zvhcv80000gn/T/ipykernel_11621/3374400604.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="aa036e20-b8d7-497e-a036-47a727bdb769" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa036e20-b8d7-497e-a036-47a727bdb769")) {                    Plotly.newPlot(                        "aa036e20-b8d7-497e-a036-47a727bdb769",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4","2016 Q1","2017 Q1","2018 Q1","2019 Q1","2020 Q1"],"xaxis":"x","y":[109950.0,105000.0,107500.0,107725.0,108000.0,106000.0,108000.0,111000.0,111000.0,113950.0,114950.0,115250.0,117750.0,123475.0,125950.0,131248.0,136950.0,139950.0,141760.0,147998.0,149000.0,154950.0,166120.0,176000.0,185000.0,189950.0,189950.0,189995.0,189950.0,184950.0,186000.0,185000.0,184300.0,192000.0,196975.0,205640.0,208995.0,214695.0,219995.0,227995.0,229995.0,226995.0,218500.0,235000.0,239950.0,245000.0,248000.0,249995.0,249995.0,249950.0,245000.0,222500.0,210000.0,195000.0,195000.0,197500.0,199000.0,210500.0,214950.0,219950.0,224950.0,231250.0,245000.0,249475.0,250000.0,249475.0,249475.0,233475.0,234950.0,232248.0,229995.0,238473.0,242995.0,250000.0,269995.0,269995.0,273973.0,287950.0,314973.0,345000.0,289975.8210526315,298774.35996240587,307572.8988721803,316371.43778195477,325169.97669172916],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca ...
# Regression summary for West Suffolk:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     332.5
# Date:                Mon, 06 May 2024   Prob (F-statistic):           7.42e-30
# Time:                        20:38:16   Log-Likelihood:                -905.86
# No. Observations:                  80   AIC:                             1816.
# Df Residuals:                      78   BIC:                             1820.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.033e+04   4367.801     18.392      0.000    7.16e+04     8.9e+04
# Year_Index  7167.0767    393.033     18.235      0.000    6384.607    7949.546
# ==============================================================================
# Omnibus:                        8.967   Durbin-Watson:                   0.135
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                5.532
# Skew:                           0.479   Prob(JB):                       0.0629
# Kurtosis:                       2.139   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/p5/8kc_v4413nsdcn4002zvhcv80000gn/T/ipykernel_11621/3374400604.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="fb854a14-2845-45fc-a882-2492da82b906" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb854a14-2845-45fc-a882-2492da82b906")) {                    Plotly.newPlot(                        "fb854a14-2845-45fc-a882-2492da82b906",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4","2016 Q1","2017 Q1","2018 Q1","2019 Q1","2020 Q1"],"xaxis":"x","y":[63497.5,65600.0,64497.5,63735.0,63349.0,66099.0,68181.5,70225.0,72037.5,76000.0,76837.5,80375.0,81852.0,86459.5,90237.5,94975.0,99622.5,98872.5,104425.0,110425.0,111562.5,114550.0,115461.5,120610.0,125722.5,139499.0,146862.5,159000.0,159124.0,146972.5,139737.5,140844.0,144085.0,156972.5,162917.5,164779.0,167746.5,183750.0,178225.0,173111.5,171236.5,168747.5,173735.5,183747.5,193747.5,201610.5,196874.0,201372.5,194999.0,177749.0,181974.0,170085.5,172651.0,169975.0,166360.0,162013.0,163237.5,161875.0,162474.0,157475.0,156250.0,153500.0,165475.0,185000.0,191496.5,191305.0,186522.5,186399.0,187000.0,187997.5,189747.5,187750.0,179250.0,188746.5,183587.5,184734.0,215495.0,219995.0,223234.0,229495.0,223676.25526315783,230843.33195488714,238010.40864661644,245177.48533834578,252344.56203007512],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f9 ...

# %% [markdown]
# ### - average for each year

# %%
df_primary_market['Year'] = df_primary_market['Year_Quarter'].str.split().str[0]

# Group by 'Year' and 'Area' to calculate average price per year per area
yearly_avg = df_primary_market.groupby(['Year', 'Area']).agg({'Price': 'mean'}).reset_index()
areas = yearly_avg['Area'].unique()

n_rows = 2
n_cols = 4
fig = make_subplots(rows=n_rows, cols=n_cols, subplot_titles=areas)


plot_row, plot_col = 1, 1

# uniform Y-axis range based on max and min of average prices

max_price = yearly_avg['Price'].max()
min_price = yearly_avg['Price'].min()

for i, area in enumerate(areas, start=1):
    area_data = yearly_avg[yearly_avg['Area'] == area]
    trace = go.Scatter(x=area_data['Year'], y=area_data['Price'], 
                       mode='lines+markers', name=area, 
                       line=dict(color='green'))
    
    fig.add_trace(trace, row=plot_row, col=plot_col)
    
    plot_col += 1
    if plot_col > n_cols: 
        plot_row += 1
        plot_col = 1
    if plot_row > n_rows and plot_col > n_cols:
        break

fig.update_yaxes(range=[min_price, max_price], nticks=10)

fig.update_layout(height=800, width=1200, title_text="Yearly Average Price Trends by District",
                  showlegend=False, template='plotly_white', title_x=0.5)

fig.show()

#Saving to HTML
fig.write_html('full_figure.html')
# Out:
# <div>                            <div id="6dfdef1c-8905-4c21-980e-d8e85e79ba3b" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dfdef1c-8905-4c21-980e-d8e85e79ba3b")) {                    Plotly.newPlot(                        "6dfdef1c-8905-4c21-980e-d8e85e79ba3b",                        [{"line":{"color":"green"},"mode":"lines+markers","name":"Cambridge","x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"],"y":[92750.5,108287.25,143937.5,145118.75,121525.0,151833.0,168803.25,204067.75,255495.75,278250.0,242473.0,246316.5,237468.75,194523.25,250000.0,258123.75,292037.5,312500.0,384681.25,461225.0],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"green"},"mode":"lines+markers","name":"East Cambridgeshire","x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"],"y":[66987.5,68743.25,78446.5,92311.25,114748.75,122112.5,148812.5,168460.25,183173.5,199480.0,185111.75,189361.25,188312.5,192474.5,191117.75,187029.5,179062.0,185000.0,208118.25,228116.25],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"green"},"mode":"lines+markers","name":"Fenland","x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"],"y":[47950.0,52462.5,55587.5,60850.0,66956.25,75775.0,99986.5,121374.5,139237.5,140237.5,137236.25,139750.0,147000.0,129187.5,130125.0,142500.0,140360.75,140123.75,145998.25,153435.75],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"line":{"color":"green"},"mode":"lines+markers","name":"Huntingdonshire","x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"],"y":[83868.25,88498.25,103486.25,127623.75,123416.25,123448.75,136730.25,162062.5,185673.25,196973.75,192591.25,208748.5,193723.25,163799.5,179393.75,189560.0,197867.5,219997.0,218618.75,201497.5],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"line":{"color":"green"},"mode":"lines+markers","name":"Peterborough","x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"],"y":[54835.75,69547.0,77178.25,85347.5,96673.0,106286.25,127673.25,142372.0,169747.5,174498.25,167372.0,168372.75,187499.5,168250.0,171462.5,171842.0,168371.25,177875.0,172248.75,179871.5],"type":"scatter","xaxis":"x5","yaxis":"y5"},{"line":{"color":"green"},"mode":"lines+markers","name":"South Cambridgeshire","x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"],"y":[107543.75,108250.0,113787.5,124605.75,141664.5,161517.5,188723.75,186475.0,194728.75,217920.0,227622.5,245736.25,241861.25,199375.0,211100.0,237668.75,245606.25,233916.5,258246.25,305474.0],"type":"scatter","xaxis":"x6","yaxis":"y6"},{"line":{"color":"green"},"mode":"lines+markers","name":"West Suffolk","x":["1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"],"y":[64332.5,66963.625,76312.5,88381.0,103336.25,115546.0,142771.0,146669.5,157188.5,175708.25,174366.75,198401.125,181201.875,167749.75,161265.375,165056.25,188930.75,188123.75,184079.5,222054.75],"type":"scatter","xaxis":"x7","yaxis":"y7"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"whi ...

# %% [markdown]
# To have a general picture of prices and their changes over the years, price trends for all districts are presented. In the case of the 'Cambridge' district, price changes are the most rapid, and the smallest differences can be observed in the case of the 'Fenland' district.

# %%
df_primary_market['Year'] = df_primary_market['Year_Quarter'].str.split().str[0]
yearly_avg = df_primary_market.groupby(['Year', 'Area']).agg({'Price': 'mean'}).reset_index()
areas = yearly_avg['Area'].unique()

output_notebook() 
output_file("district_price_trends_primary_market.html") 

p = figure(title="Yearly Average Price Trends by District on the Primary Market", x_axis_label='Year', y_axis_label='Price',
           tools="pan,wheel_zoom,box_zoom,reset,save", width=1000, height=400)

p.title.align = 'center' 
colors = Category10[10] 

legend_items = []

for i, area in enumerate(areas):
    color = colors[i % len(colors)] 
    area_data = yearly_avg[yearly_avg['Area'] == area]
    source = ColumnDataSource(area_data)
    line = p.line(x='Year', y='Price', line_width=2, color=color, source=source)
    
    circle = p.circle(x='Year', y='Price', fill_color=color, line_color=color, size=8, source=source)

    legend_items.append(LegendItem(label=area, renderers=[line, circle]))

p.yaxis.formatter = NumeralTickFormatter(format="0a") 

custom_legend = Legend(items=legend_items, location="top_left")
p.add_layout(custom_legend, 'right')
p.legend.click_policy="hide" 

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a15404e0-b5d8-441d-bb4c-98f4731834f7">Loading BokehJS ...</span>
#     </div>
#   <div id="ca0e5999-5358-45ed-ac46-0d59a7c4d1cf" data-root-id="p1640" style="display: contents;"></div>

# %% [markdown]
# ### RESALE MARKET

# %%
df_resale_market['Year_Quarter'] = df_resale_market['Year'].astype(str) + ' ' + df_resale_market['Quarter']
df_resale_market.sort_values(by='Year_Quarter', inplace=True)

areas = df_resale_market['Area'].unique()


for area in areas:
    area_data = df_primary_market[df_primary_market['Area'] == area]
    
    # Extract only the year part from 'Year_Quarter' for ticks
    labels = area_data['Year_Quarter'].tolist()
    year_ticks = [label for index, label in enumerate(labels) if index % 4 == 0] 
    fig = px.line(area_data, x='Year_Quarter', y='Price', 
                  title=f'Price Trend for {area}', 
                  labels={'Year_Quarter': 'Year and Quarter', 'Price': 'Price'},
                  markers=True,
                  color_discrete_sequence=['green']) 

    fig.update_xaxes(tickvals=[labels.index(tick) for tick in year_ticks], ticktext=[tick.split()[0] for tick in year_ticks])
    
    fig.update_layout(
        xaxis_title='Year and Quarter',
        yaxis_title='Price',
        xaxis=dict(tickangle=45),
        template='plotly_white',
        autosize=True
    )
    
    fig.show()
# Out:
# <div>                            <div id="c8fa4374-df39-4965-81ea-34811ec365dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8fa4374-df39-4965-81ea-34811ec365dc")) {                    Plotly.newPlot(                        "c8fa4374-df39-4965-81ea-34811ec365dc",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4"],"xaxis":"x","y":[90000.0,93525.0,92500.0,94977.0,92950.0,99995.0,115000.0,125204.0,150000.0,147000.0,140750.0,138000.0,130000.0,145000.0,165500.0,139975.0,117100.0,121500.0,121500.0,126000.0,138000.0,138000.0,195000.0,136332.0,134995.0,169995.0,170223.0,200000.0,221300.0,200000.0,194998.0,199973.0,204998.0,249995.0,276995.0,289995.0,285000.0,275500.0,277500.0,275000.0,275000.0,235401.0,230326.0,229165.0,230602.0,250000.0,249375.0,255289.0,262000.0,261625.0,245000.0,181250.0,165119.0,153000.0,209975.0,249999.0,250000.0,250000.0,250000.0,250000.0,250000.0,250000.0,250000.0,282495.0,282500.0,300000.0,304000.0,281650.0,285000.0,310000.0,315000.0,340000.0,350250.0,362500.0,406000.0,419975.0,430000.0,445000.0,469950.0,499950.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4 ...
# <div>                            <div id="7e916402-0522-4924-8368-9794416f4aa0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e916402-0522-4924-8368-9794416f4aa0")) {                    Plotly.newPlot(                        "7e916402-0522-4924-8368-9794416f4aa0",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4"],"xaxis":"x","y":[69950.0,68000.0,65500.0,64500.0,65500.0,66973.0,70000.0,72500.0,73000.0,75738.0,79325.0,85723.0,88995.0,91250.0,94000.0,95000.0,106995.0,115000.0,117000.0,120000.0,120500.0,119950.0,123000.0,125000.0,131000.0,144250.0,155000.0,165000.0,167575.0,168075.0,168196.0,169995.0,174449.0,175000.0,189995.0,193250.0,199995.0,200000.0,199950.0,197975.0,189475.0,184973.0,184999.0,181000.0,187750.0,187450.0,189995.0,192250.0,185900.0,186700.0,186950.0,193700.0,200000.0,200000.0,185150.0,184748.0,184998.0,184998.0,195000.0,199475.0,194498.0,189495.0,182125.0,182000.0,180000.0,179500.0,179500.0,177248.0,182500.0,182500.0,185000.0,190000.0,190000.0,215000.0,217498.0,209975.0,219995.0,219995.0,235000.0,237475.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0 ...
# <div>                            <div id="4468762b-b780-45b3-b0f6-340944ef507a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4468762b-b780-45b3-b0f6-340944ef507a")) {                    Plotly.newPlot(                        "4468762b-b780-45b3-b0f6-340944ef507a",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q
                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4"],"xaxis":"x","y":[109950.0,105000.0,107500.0,107725.0,108000.0,106000.0,108000.0,111000.0,111000.0,113950.0,114950.0,115250.0,117750.0,123475.0,125950.0,131248.0,136950.0,139950.0,141760.0,147998.0,149000.0,154950.0,166120.0,176000.0,185000.0,189950.0,189950.0,189995.0,189950.0,184950.0,186000.0,185000.0,184300.0,192000.0,196975.0,205640.0,208995.0,214695.0,219995.0,227995.0,229995.0,226995.0,218500.0,235000.0,239950.0,245000.0,248000.0,249995.0,249995.0,249950.0,245000.0,222500.0,210000.0,195000.0,195000.0,197500.0,199000.0,210500.0,214950.0,219950.0,224950.0,231250.0,245000.0,249475.0,250000.0,249475.0,249475.0,233475.0,234950.0,232248.0,229995.0,238473.0,242995.0,250000.0,269995.0,269995.0,273973.0,287950.0,314973.0,345000.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111111 ...
# <div>                            <div id="3baccb7b-3312-4718-99a3-853ed63782ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3baccb7b-3312-4718-99a3-853ed63782ed")) {                    Plotly.newPlot(                        "3baccb7b-3312-4718-99a3-853ed63782ed",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4"],"xaxis":"x","y":[63497.5,65600.0,64497.5,63735.0,63349.0,66099.0,68181.5,70225.0,72037.5,76000.0,76837.5,80375.0,81852.0,86459.5,90237.5,94975.0,99622.5,98872.5,104425.0,110425.0,111562.5,114550.0,115461.5,120610.0,125722.5,139499.0,146862.5,159000.0,159124.0,146972.5,139737.5,140844.0,144085.0,156972.5,162917.5,164779.0,167746.5,183750.0,178225.0,173111.5,171236.5,168747.5,173735.5,183747.5,193747.5,201610.5,196874.0,201372.5,194999.0,177749.0,181974.0,170085.5,172651.0,169975.0,166360.0,162013.0,163237.5,161875.0,162474.0,157475.0,156250.0,153500.0,165475.0,185000.0,191496.5,191305.0,186522.5,186399.0,187000.0,187997.5,189747.5,187750.0,179250.0,188746.5,183587.5,184734.0,215495.0,219995.0,223234.0,229495.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2 ...

# %%
# For each area, fit a linear regression model and forecast prices
for area in areas:
    area_data = df_resale_market[df_resale_market['Area'] == area]

    # prepare data for regression
    area_data['Year_Index'] = area_data['Year'].astype(int) - area_data['Year'].astype(int).min()
    X = add_constant(area_data['Year_Index']) 
    y = area_data['Price']

    # Fit the regression model
    model = OLS(y, X).fit()
    
    # Print summary of regression
    print(f"Regression summary for {area}:\n", model.summary())

    # forecast for the next 5 years
    forecast_years = pd.DataFrame({'Year_Index': range(area_data['Year_Index'].max() + 1, area_data['Year_Index'].max() + 6)})
    forecast_years = add_constant(forecast_years) 
    predictions = model.predict(forecast_years)

    # create a DataFrame for plotting forecasted values
    forecasted_data = pd.DataFrame({
        'Year_Quarter': [str(year) + ' Q1' for year in range(area_data['Year'].max() + 1, area_data['Year'].max() + 6)],
        'Price': predictions
    })

    # combine historical and forecasted data
    combined_data = pd.concat([area_data, forecasted_data])

    # Plotting with Plotly
    fig = px.line(combined_data, x='Year_Quarter', y='Price', 
                  title=f'Price Trend and Forecast for {area}', 
                  labels={'Year_Quarter': 'Year and Quarter', 'Price': 'Price'},
                  markers=True,
                  color_discrete_sequence=['green'])

    fig.update_layout(
        xaxis_title='Year and Quarter',
        yaxis_title='Price',
        xaxis=dict(tickangle=45),
        template='plotly_white',
        autosize=True
    )

    fig.show()
# Out:
# Regression summary for Cambridge:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     2083.
# Date:                Mon, 06 May 2024   Prob (F-statistic):           5.00e-58
# Time:                        20:38:19   Log-Likelihood:                -884.89
# No. Observations:                  80   AIC:                             1774.
# Df Residuals:                      78   BIC:                             1779.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        6.87e+04   3360.620     20.442      0.000     6.2e+04    7.54e+04
# Year_Index   1.38e+04    302.403     45.645      0.000    1.32e+04    1.44e+04
# ==============================================================================
# Omnibus:                        4.828   Durbin-Watson:                   0.260
# Prob(Omnibus):                  0.089   Jarque-Bera (JB):                4.444
# Skew:                           0.576   Prob(JB):                        0.108
# Kurtosis:                       3.067   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/p5/8kc_v4413nsdcn4002zvhcv80000gn/T/ipykernel_11621/3648608833.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="fad7e7ad-d8b4-4e35-b482-00aa4b9994b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fad7e7ad-d8b4-4e35-b482-00aa4b9994b2")) {                    Plotly.newPlot(                        "fad7e7ad-d8b4-4e35-b482-00aa4b9994b2",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4","2016 Q1","2017 Q1","2018 Q1","2019 Q1","2020 Q1"],"xaxis":"x","y":[69950.0,70000.0,72000.0,72500.0,73000.0,75000.0,78500.0,82500.0,85500.0,88000.0,90000.0,92500.0,94000.0,96500.0,99950.0,101000.0,106000.0,110000.0,118000.0,125000.0,126000.0,130000.0,136000.0,140000.0,147000.0,153500.0,160000.0,168000.0,175000.0,180000.0,181500.0,185000.0,186000.0,187000.0,190000.0,195000.0,195000.0,201250.0,206000.0,210000.0,214000.0,218000.0,220000.0,227500.0,235500.0,243000.0,249950.0,250000.0,250000.0,250000.0,249950.0,244000.0,240000.0,232500.0,230000.0,230000.0,240000.0,249000.0,250000.0,265000.0,258998.0,262750.0,258000.0,262000.0,263000.0,265500.0,270000.0,275000.0,283000.0,283975.0,290000.0,295000.0,295000.0,304075.0,315000.0,327350.0,337000.0,350000.0,370000.0,380000.0,344761.0828947368,358564.28364661644,372367.48439849616,386170.6851503759,399973.88590225554],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f ...
# Regression summary for East Cambridgeshire:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     813.6
# Date:                Mon, 06 May 2024   Prob (F-statistic):           5.12e-43
# Time:                        20:38:19   Log-Likelihood:                -886.78
# No. Observations:                  80   AIC:                             1778.
# Df Residuals:                      78   BIC:                             1782.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.117e+04   3441.320     17.777      0.000    5.43e+04     6.8e+04
# Year_Index  8832.6481    309.665     28.523      0.000    8216.153    9449.143
# ==============================================================================
# Omnibus:                       22.100   Durbin-Watson:                   0.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.672
# Skew:                           0.577   Prob(JB):                       0.0131
# Kurtosis:                       1.874   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/p5/8kc_v4413nsdcn4002zvhcv80000gn/T/ipykernel_11621/3648608833.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="af7722f8-3e58-4abe-869f-8a6e9e8b8cd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af7722f8-3e58-4abe-869f-8a6e9e8b8cd7")) {                    Plotly.newPlot(                        "af7722f8-3e58-4abe-869f-8a6e9e8b8cd7",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q

# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.639e+04   3575.715     15.769      0.000    4.93e+04    6.35e+04
# Year_Index  8281.2735    321.758     25.738      0.000    7640.702    8921.845
# ==============================================================================
# Omnibus:                       21.820   Durbin-Watson:                   0.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.678
# Skew:                           0.503   Prob(JB):                       0.0215
# Kurtosis:                       1.864   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/p5/8kc_v4413nsdcn4002zvhcv80000gn/T/ipykernel_11621/3648608833.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="19b12261-a3ed-4444-be09-cf1e0bbb5fe4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19b12261-a3ed-4444-be09-cf1e0bbb5fe4")) {                    Plotly.newPlot(                        "19b12261-a3ed-4444-be09-cf1e0bbb5fe4",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4","2016 Q1","2017 Q1","2018 Q1","2019 Q1","2020 Q1"],"xaxis":"x","y":[54000.0,54000.0,54625.0,54875.0,55000.0,56000.0,57000.0,58000.0,59200.0,59995.0,60000.0,60000.0,62000.0,64000.0,67000.0,69000.0,70000.0,73500.0,75750.0,79950.0,82000.0,84250.0,86000.0,89375.0,91500.0,95995.0,106000.0,112500.0,116000.0,122000.0,128000.0,132000.0,135000.0,140000.0,146500.0,150000.0,153000.0,155000.0,156000.0,159995.0,160000.0,161500.0,166000.0,168000.0,170000.0,174995.0,175500.0,178000.0,183000.0,180000.0,180000.0,176500.0,172000.0,170000.0,167750.0,168000.0,170000.0,174000.0,175000.0,180000.0,177500.0,175000.0,172500.0,170000.0,168000.0,170000.0,174995.0,175000.0,180000.0,179000.0,177000.0,178000.0,179995.0,184500.0,190000.0,195000.0,198000.0,200000.0,210000.0,215000.0,222012.68421052626,230293.95770676684,238575.23120300745,246856.50469924806,255137.77819548867],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"t ...
# Regression summary for Peterborough:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                     419.2
# Date:                Mon, 06 May 2024   Prob (F-statistic):           4.16e-33
# Time:                        20:38:19   Log-Likelihood:                -881.94
# No. Observations:                  80   AIC:                             1768.
# Df Residuals:                      78   BIC:                             1773.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.141e+04   3239.211     12.783      0.000     3.5e+04    4.79e+04
# Year_Index  5967.5177    291.478     20.473      0.000    5387.230    6547.806
# ==============================================================================
# Omnibus:                       12.884   Durbin-Watson:                   0.052
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.769
# Skew:                           0.674   Prob(JB):                       0.0125
# Kurtosis:                       2.097   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/p5/8kc_v4413nsdcn4002zvhcv80000gn/T/ipykernel_11621/3648608833.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="9d90d03a-96af-4e7c-b628-97726368d292" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d90d03a-96af-4e7c-b628-97726368d292")) {                    Plotly.newPlot(                        "9d90d03a-96af-4e7c-b628-97726368d292",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4","2016 Q1","2017 Q1","2018 Q1","2019 Q1","2020 Q1"],"xaxis":"x","y":[40000.0,40000.0,40000.0,41000.0,41500.0,42000.0,43000.0,43500.0,44000.0,44000.0,45000.0,45000.0,45500.0,46000.0,46995.0,48000.0,48500.0,49995.0,50500.0,52500.0,53250.0,56000.0,58500.0,60000.0,64000.0,67500.0,72000.0,76995.0,79995.0,83998.0,88000.0,93000.0,96000.0,101000.0,109995.0,115000.0,116000.0,118625.0,119950.0,119500.0,120000.0,123000.0,125000.0,129995.0,130500.0,134000.0,135798.0,137000.0,138000.0,137995.0,135000.0,131000.0,130000.0,125000.0,125000.0,125250.0,125000.0,125000.0,127000.0,125000.0,127500.0,128000.0,125000.0,125000.0,125000.0,125000.0,125000.0,125000.0,125000.0,125000.0,125000.0,125000.0,129250.0,132750.0,135100.0,138000.0,140000.0,143500.0,145000.0,148000.0,160758.13552631575,166725.65319548867,172693.1708646616,178660.68853383453,184628.20620300746],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"he ...
# Regression summary for South Cambridgeshire:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     1090.
# Date:                Mon, 06 May 2024   Prob (F-statistic):           1.36e-47
# Time:                        20:38:19   Log-Likelihood:                -894.20
# No. Observations:                  80   AIC:                             1792.
# Df Residuals:                      78   BIC:                             1797.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.772e+04   3775.682     20.583      0.000    7.02e+04    8.52e+04
# Year_Index  1.122e+04    339.752     33.011      0.000    1.05e+04    1.19e+04
# ==============================================================================
# Omnibus:                       11.090   Durbin-Watson:                   0.151
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):                6.731
# Skew:                           0.548   Prob(JB):                       0.0346
# Kurtosis:                       2.095   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/p5/8kc_v4413nsdcn4002zvhcv80000gn/T/ipykernel_11621/3648608833.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="bd56ff3f-9c5a-45b5-a909-5bf5fc3795f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd56ff3f-9c5a-45b5-a909-5bf5fc3795f1")) {                    Plotly.newPlot(                        "bd56ff3f-9c5a-45b5-a909-5bf5fc3795f1",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4","2016 Q1","2017 Q1","2018 Q1","2019 Q1","2020 Q1"],"xaxis":"x","y":[70000.0,70000.0,73125.0,74000.0,74000.0,75500.0,77500.0,79950.0,82500.0,85000.0,88000.0,90000.0,92500.0,95000.0,98000.0,99950.0,102000.0,105000.0,110500.0,119500.0,122000.0,126000.0,131500.0,135000.0,139972.0,144950.0,152000.0,159000.0,163500.0,169500.0,175000.0,176975.0,180000.0,185000.0,187000.0,192000.0,195000.0,196000.0,200000.0,202500.0,205000.0,207750.0,215000.0,215000.0,220000.0,227250.0,235000.0,240000.0,245000.0,246000.0,246250.0,239998.0,225000.0,215000.0,212500.0,218000.0,225000.0,227500.0,233500.0,235000.0,235000.0,237500.0,235000.0,240500.0,239950.0,240000.0,242000.0,242750.0,249500.0,249950.0,250000.0,250000.0,250000.0,250000.0,259875.0,266500.0,275000.0,284000.0,300000.0,315000.0,302029.2684210526,313244.91898496234,324460.5695488721,335676.2201127819,346891.87067669164],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f92 ...
# Regression summary for West Suffolk:
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     608.7
# Date:                Mon, 06 May 2024   Prob (F-statistic):           1.38e-38
# Time:                        20:38:19   Log-Likelihood:                -888.89
# No. Observations:                  80   AIC:                             1782.
# Df Residuals:                      78   BIC:                             1787.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.425e+04   3533.044     15.355      0.000    4.72e+04    6.13e+04
# Year_Index  7843.4263    317.918     24.671      0.000    7210.500    8476.353
# ==============================================================================
# Omnibus:                       16.227   Durbin-Watson:                   0.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.604
# Skew:                           0.623   Prob(JB):                       0.0135
# Kurtosis:                       1.986   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/p5/8kc_v4413nsdcn4002zvhcv80000gn/T/ipykernel_11621/3648608833.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="bd67c8a7-de56-435e-b655-85a834a9dc7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd67c8a7-de56-435e-b655-85a834a9dc7d")) {                    Plotly.newPlot(                        "bd67c8a7-de56-435e-b655-85a834a9dc7d",                        [{"hovertemplate":"Year and Quarter=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","line":{"color":"green","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1996 Q1","1996 Q2","1996 Q3","1996 Q4","1997 Q1","1997 Q2","1997 Q3","1997 Q4","1998 Q1","1998 Q2","1998 Q3","1998 Q4","1999 Q1","1999 Q2","1999 Q3","1999 Q4","2000 Q1","2000 Q2","2000 Q3","2000 Q4","2001 Q1","2001 Q2","2001 Q3","2001 Q4","2002 Q1","2002 Q2","2002 Q3","2002 Q4","2003 Q1","2003 Q2","2003 Q3","2003 Q4","2004 Q1","2004 Q2","2004 Q3","2004 Q4","2005 Q1","2005 Q2","2005 Q3","2005 Q4","2006 Q1","2006 Q2","2006 Q3","2006 Q4","2007 Q1","2007 Q2","2007 Q3","2007 Q4","2008 Q1","2008 Q2","2008 Q3","2008 Q4","2009 Q1","2009 Q2","2009 Q3","2009 Q4","2010 Q1","2010 Q2","2010 Q3","2010 Q4","2011 Q1","2011 Q2","2011 Q3","2011 Q4","2012 Q1","2012 Q2","2012 Q3","2012 Q4","2013 Q1","2013 Q2","2013 Q3","2013 Q4","2014 Q1","2014 Q2","2014 Q3","2014 Q4","2015 Q1","2015 Q2","2015 Q3","2015 Q4","2016 Q1","2017 Q1","2018 Q1","2019 Q1","2020 Q1"],"xaxis":"x","y":[51250.0,50812.5,50987.5,51497.5,52000.0,53312.5,54750.0,55500.0,55500.0,56999.5,58485.5,59625.0,61125.0,62475.0,63250.0,64986.5,66500.0,69500.0,72250.0,74997.5,77000.0,79250.0,82500.0,85437.5,89897.5,96250.0,101936.5,106500.0,112250.0,118311.5,123500.0,127500.0,131500.0,135750.0,142124.0,147375.0,149000.0,151500.0,151000.0,150500.0,150625.0,152484.0,156500.0,159500.0,162500.0,166112.5,168500.0,172500.0,176000.0,177497.5,175750.0,169000.0,162750.0,156000.0,152500.0,153750.0,155875.0,158750.0,162750.0,166000.0,165250.0,164875.0,164975.0,162100.0,160500.0,162000.0,164837.5,165000.0,168000.0,168000.0,167999.5,170000.0,171750.0,175500.0,184000.0,189975.0,191750.0,197500.0,201374.0,205250.0,211116.80131578943,218960.2276315789,226803.65394736838,234647.08026315784,242490.5065789473],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"typ ...

# %%
df_resale_market['Year'] = df_resale_market['Year_Quarter'].str.split().str[0]
yearly_avg = df_resale_market.groupby(['Year', 'Area']).agg({'Price': 'mean'}).reset_index()
areas = yearly_avg['Area'].unique()

output_notebook() 
output_file("district_price_trends_resale_market.html") 

p = figure(title="Yearly Average Price Trends by District on the Resale Market", x_axis_label='Year', y_axis_label='Price',
           tools="pan,wheel_zoom,box_zoom,reset,save", width=1000, height=400)

p.title.align = 'center' 
colors = Category10[10] 

legend_items = []

for i, area in enumerate(areas):
    color = colors[i % len(colors)] 
    area_data = yearly_avg[yearly_avg['Area'] == area]
    source = ColumnDataSource(area_data)
    line = p.line(x='Year', y='Price', line_width=2, color=color, source=source)
    
    circle = p.circle(x='Year', y='Price', fill_color=color, line_color=color, size=8, source=source)

    legend_items.append(LegendItem(label=area, renderers=[line, circle]))

p.yaxis.formatter = NumeralTickFormatter(format="0a") 

custom_legend = Legend(items=legend_items, location="top_left")
p.add_layout(custom_legend, 'right')
p.legend.click_policy="hide" 

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="aef23f11-3784-4e13-8494-1f9f9d4d96fc">Loading BokehJS ...</span>
#     </div>
#   <div id="f374e032-b5a7-458c-8721-df430abcfa92" data-root-id="p1853" style="display: contents;"></div>

# %% [markdown]
# The lines show a clear upward trend in prices over these two decades, indicating that houses in all districts have generally become more expensive over time.

# %% [markdown]
# ### DEEP DIVE - FENLAND DISTRICT

# %% [markdown]
# Our special attention was drawn to the Fenland district, where the median price of apartments on the primary market was the lowest in all recorded years and the growth rate was the lowest. However, on the secondary market, the median apartment price is no longer the lowest, and the growth dynamics examined using linear regression turned out to be higher than in the case of the Peterborough district. Buying a flat in Fenland may be a good investment if your budget is not the highest and you want to be the first owner of the property.

# %%
df_resale_market
# Out:
#       ONS code                 Area Quarter  Houses Sold  Year     Price  \
# 0    E07000008            Cambridge      Q1         1438  1996   69950.0
# 1    E07000009  East Cambridgeshire      Q1          940  1996   56500.0
# 2    E07000010              Fenland      Q1         1214  1996   40000.0
# 3    E07000011      Huntingdonshire      Q1         2575  1996   54000.0
# 4    E06000031         Peterborough      Q1         2212  1996   40000.0
# ..         ...                  ...     ...          ...   ...       ...
# 554  E07000009  East Cambridgeshire      Q4         1312  2015  240000.0
# 555  E07000010              Fenland      Q4         1660  2015  150000.0
# 556  E07000011      Huntingdonshire      Q4         2938  2015  215000.0
# 557  E06000031         Peterborough      Q4         2488  2015  148000.0
# 559  E07000245         West Suffolk      Q4         2895  2015  205250.0
#
#     Year_Quarter
# 0        1996 Q1
# 1        1996 Q1
# 2        1996 Q1
# 3        1996 Q1
# 4        1996 Q1
# ..           ...
# 554      2015 Q4
# 555      2015 Q4
# 556      2015 Q4
# 557      2015 Q4
# 559      2015 Q4
#
# [560 rows x 7 columns]

# %%
fenland_primary
# Out:
#       ONS code     Area Quarter  Houses Sold  Year     Price Year_Quarter
# 2    E07000010  Fenland      Q1          252  1996   47950.0      1996 Q1
# 9    E07000010  Fenland      Q2          215  1996   47950.0      1996 Q2
# 16   E07000010  Fenland      Q3          209  1996   47950.0      1996 Q3
# 23   E07000010  Fenland      Q4          199  1996   47950.0      1996 Q4
# 30   E07000010  Fenland      Q1          211  1997   47950.0      1997 Q1
# ..         ...      ...     ...          ...   ...       ...          ...
# 527  E07000010  Fenland      Q4          126  2014  149995.0      2014 Q4
# 534  E07000010  Fenland      Q1          117  2015  149995.0      2015 Q1
# 541  E07000010  Fenland      Q2           92  2015  153998.0      2015 Q2
# 548  E07000010  Fenland      Q3           86  2015  157250.0      2015 Q3
# 555  E07000010  Fenland      Q4           78  2015  152500.0      2015 Q4
#
# [80 rows x 7 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch

# Filter data for Fenland area
fenland_primary = df_primary_market[df_primary_market['Area'] == 'Fenland']
fenland_resale = df_resale_market[df_resale_market['Area'] == 'Fenland']

# Pivot the data to get years as rows and quarters as columns
pivot_primary = fenland_primary.pivot(index='Year', columns='Quarter', values='Price')
pivot_resale = fenland_resale.pivot(index='Year', columns='Quarter', values='Price')

def apply_custom_coloring(pivot_table):
    color_mask = pd.DataFrame(np.nan, index=pivot_table.index, columns=pivot_table.columns)

    for year in pivot_table.index:
        year_data = pivot_table.loc[year].dropna()
        if not year_data.empty:
            if year_data.nunique() == 1:  # Check if all values are the same
                color_mask.loc[year, :] = 2  # Assign a unique value for uniform prices
            else:
                min_price = year_data.min()
                max_price = year_data.max()
                
                min_quarter = year_data[year_data == min_price].index[0] if not year_data[year_data == min_price].empty else None
                max_quarter = year_data[year_data == max_price].index[0] if not year_data[year_data == max_price].empty else None
                
                if min_quarter and max_quarter:
                    color_mask.loc[year, min_quarter] = 0  # Min
                    color_mask.loc[year, max_quarter] = 1  # Max

    return color_mask.astype(float)

color_mask_primary = apply_custom_coloring(pivot_primary)
color_mask_resale = apply_custom_coloring(pivot_resale)

# Define a colormap with an additional color for uniform price years
cmap = ListedColormap(['blue', 'red', 'gray'])

fig, ax = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

sns.heatmap(color_mask_primary, cmap=cmap, ax=ax[0], cbar=False, mask=color_mask_primary.isnull())
ax[0].set_title('Primary Market Prices for Fenland')
ax[0].set_xlabel('Quarter')
ax[0].set_ylabel('Year')

sns.heatmap(color_mask_resale, cmap=cmap, ax=ax[1], cbar=False, mask=color_mask_resale.isnull())
ax[1].set_title('Resale Market Prices for Fenland')
ax[1].set_xlabel('Quarter')
ax[1].set_ylabel('Year')

# Adding legend
legend_elements = [
    Patch(facecolor='red', label='Highest Price'),
    Patch(facecolor='blue', label='Lowest Price'),
    Patch(facecolor='gray', label='Uniform Price')
]
fig.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.models import ColorBar, ColumnDataSource, LinearColorMapper, BasicTicker, PrintfTickFormatter
from bokeh.transform import transform
from bokeh.layouts import row
from bokeh.io import output_notebook

output_notebook()  # Wyświetlanie wykresów Bokeh w Jupyter Notebook

# Załóżmy, że 'color_mask_primary' i 'color_mask_resale' są już zdefiniowane

# Przygotowanie danych
data_primary = color_mask_primary.stack().reset_index()
data_primary.columns = ['Year', 'Quarter', 'Price']

data_resale = color_mask_resale.stack().reset_index()
data_resale.columns = ['Year', 'Quarter', 'Price']

# Tworzenie źródła danych dla Bokeh
source_primary = ColumnDataSource(data_primary)
source_resale = ColumnDataSource(data_resale)

# Definicja mapy kolorów
color_mapper = LinearColorMapper(palette=['#78c679', '#31a354', '#006837'], low=0, high=1)

def create_heatmap(source, title):
    p = figure(title=title, 
               x_range=(data_primary['Year'].astype(str).unique()), 
               y_range=list(reversed(data_primary['Quarter'].unique())),
               x_axis_label='Year', y_axis_label='Quarter', 
               tools="", toolbar_location=None,
               width=600, height=300)
    p.rect(x='Year', y='Quarter', width=1, height=1, source=source,
           line_color=None, fill_color=transform('Price', color_mapper))
    # Dodanie paska kolorów bez wartości liczbowych
    color_bar = ColorBar(color_mapper=color_mapper, label_standoff=12, location=(0,0),
                         title='Price Level', orientation='vertical',
                         ticker=BasicTicker(desired_num_ticks=3),
                         formatter=PrintfTickFormatter(format=''))  # Formatowanie etykiet na pasku kolorów
    p.add_layout(color_bar, 'right')

    # Modyfikacja wartości na osi Y, aby były pionowe
    p.yaxis.major_label_orientation = "vertical"

    p.grid.grid_line_color = None
    return p

# Tworzenie map ciepła
heatmap_primary = create_heatmap(source_primary, "Primary Market Prices for Fenland")
heatmap_resale = create_heatmap(source_resale, "Resale Market Prices for Fenland")

# Wyświetlanie map ciepła obok siebie
show(row(heatmap_primary, heatmap_resale))
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ca529969-bec1-49a0-b5b7-c125f5598471">Loading BokehJS ...</span>
#     </div>
#   <div id="ebc1e2cd-1d63-43a9-b1d2-eab0e262b84c" data-root-id="p2522" style="display: contents;"></div>

# %%
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.models import ColorBar, ColumnDataSource, LinearColorMapper, BasicTicker, PrintfTickFormatter
from bokeh.transform import transform
from bokeh.layouts import row
from bokeh.io import output_notebook

output_notebook()  # Wyświetlanie wykresów Bokeh w Jupyter Notebook

# Załóżmy, że 'color_mask_primary' i 'color_mask_resale' są już zdefiniowane

# Przygotowanie danych
data_primary = color_mask_primary.stack().reset_index()
data_primary.columns = ['Year', 'Quarter', 'Price']

data_resale = color_mask_resale.stack().reset_index()
data_resale.columns = ['Year', 'Quarter', 'Price']

# Tworzenie źródła danych dla Bokeh
source_primary = ColumnDataSource(data_primary)
source_resale = ColumnDataSource(data_resale)

# Definicja mapy kolorów - zaktualizowana o słowne etykiety
color_mapper = LinearColorMapper(palette=['#78c679', '#31a354', '#006837'], low=min(data_primary['Price']), high=max(data_primary['Price']))

def create_heatmap(source, title):
    p = figure(title=title, 
               x_range=(data_primary['Year'].astype(str).unique()), 
               y_range=list(reversed(data_primary['Quarter'].unique())),
               x_axis_label='Year', y_axis_label='Quarter', 
               tools="", toolbar_location=None,
               width=600, height=300)
    p.rect(x='Year', y='Quarter', width=1, height=1, source=source,
           line_color=None, fill_color=transform('Price', color_mapper))
    
    # Dodanie paska kolorów z wartościami słownymi
    color_bar = ColorBar(color_mapper=color_mapper, label_standoff=12, location=(0,0),
                         title='Price Level', orientation='vertical',
                         ticker=BasicTicker(desired_num_ticks=len(color_mapper.palette)),
                         major_label_overrides={str(color_mapper.low): 'low', str(color_mapper.high): 'high'})
    p.add_layout(color_bar, 'right')

    # Modyfikacja wartości na osi Y, aby były pionowe
    p.yaxis.major_label_orientation = "vertical"

    # Ustawienie wartości na osi X tylko co drugi rok
    p.xaxis.major_label_overrides = {str(i): str(i) if int(i) % 2 == 0 else '' for i in data_primary['Year'].astype(str).unique()}

    p.grid.grid_line_color = None
    return p

# Tworzenie map ciepła
heatmap_primary = create_heatmap(source_primary, "Primary Market Prices for Fenland")
heatmap_resale = create_heatmap(source_resale, "Resale Market Prices for Fenland")

# Wyświetlanie map ciepła obok siebie
show(row(heatmap_primary, heatmap_resale))
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f9d78447-18bb-411a-96e4-e7d5c5411359">Loading BokehJS ...</span>
#     </div>
#   <div id="fed05563-f577-49bc-9736-331e8f09410d" data-root-id="p3071" style="display: contents;"></div>

# %%
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.models import ColorBar, ColumnDataSource, LinearColorMapper, BasicTicker, PrintfTickFormatter, FactorRange
from bokeh.transform import transform
from bokeh.layouts import row
from bokeh.io import output_notebook

output_notebook()  # Wyświetlanie wykresów Bokeh w Jupyter Notebook

# Załóżmy, że 'color_mask_primary' i 'color_mask_resale' są już zdefiniowane

# Przygotowanie danych
data_primary = color_mask_primary.stack().reset_index()
data_primary.columns = ['Year', 'Quarter', 'Price']

data_resale = color_mask_resale.stack().reset_index()
data_resale.columns = ['Year', 'Quarter', 'Price']

# Dodaj logikę wypełniania kolorami
def apply_color_logic(df):
    df['Color'] = 2  # Domyślnie ustaw wszystkie wartości na kolor trzeci
    for year in df['Year'].unique():
        yearly_data = df[df['Year'] == year]
        min_price = yearly_data['Price'].min()
        max_price = yearly_data['Price'].max()
        df.loc[(df['Year'] == year) & (df['Price'] == min_price), 'Color'] = 0
        df.loc[(df['Year'] == year) & (df['Price'] == max_price), 'Color'] = 1
    return df

data_primary = apply_color_logic(data_primary)
data_resale = apply_color_logic(data_resale)

# Tworzenie źródła danych dla Bokeh
source_primary = ColumnDataSource(data_primary)
source_resale = ColumnDataSource(data_resale)

# Definicja mapy kolorów
color_mapper = LinearColorMapper(palette=['#78c679', '#31a354', '#006837'], low=0, high=2)

def create_heatmap(source, title):
    df = pd.DataFrame(source.data)
    years = sorted(df['Year'].unique())
    visible_years = [year for i, year in enumerate(years) if i % 2 == 0]  # Wybór tylko co drugiego roku

    p = figure(title=title,
               x_range=FactorRange(*visible_years),
               y_range=list(reversed(df['Quarter'].unique())),
               x_axis_label='Year', y_axis_label='Quarter',
               tools="", toolbar_location=None,
               width=600, height=300)
    p.rect(x='Year', y='Quarter', width=1, height=1, source=source,
           line_color=None, fill_color=transform('Color', color_mapper))
    color_bar = ColorBar(color_mapper=color_mapper, label_standoff=12, location=(0,0),
                         title='Price Level', orientation='vertical',
                         ticker=BasicTicker(desired_num_ticks=3),
                         formatter=PrintfTickFormatter(format=''))
    p.add_layout(color_bar, 'right')
    p.yaxis.major_label_orientation = "vertical"
    p.grid.grid_line_color = None
    return p

# Tworzenie map ciepła
heatmap_primary = create_heatmap(source_primary, "Primary Market Prices for Fenland")
heatmap_resale = create_heatmap(source_resale, "Resale Market Prices for Fenland")

# Wyświetlanie map ciepła obok siebie
show(row(heatmap_primary, heatmap_resale))
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ca116cab-5eab-40c9-b4d0-b66077bd75d2">Loading BokehJS ...</span>
#     </div>
#   <div id="e9a0514a-8fa7-433d-a380-11c45c324f21" data-root-id="p2711" style="display: contents;"></div>
